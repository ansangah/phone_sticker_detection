# %% [markdown]
# <a href="https://colab.research.google.com/github/ansangah/phone_sticker_detection/blob/samingming/phone_sticker_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
# !pip install roboflow

import getpass
from roboflow import Roboflow

API_KEY = getpass.getpass("Roboflow API key: ")

rf = Roboflow(api_key=API_KEY)
project = rf.workspace("-k8kkf").project("phone_sticker_detection")
dataset = project.version(1).download("yolov8")

# %%
from ultralytics import YOLO

model = YOLO("yolov8s-seg.pt")  # 모델 업그레이드 (n → s)

model.train(
    data="/content/phone_sticker_detection-1/data.yaml",
    epochs=100,   # 학습 더 오래
    imgsz=640
)

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/segment/train-2/weights/best.pt")

results = model.predict(
    source="/content/phone_sticker_detection-1/test/images",
    save=True,
    conf=0.25
)

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/segment/train-3/weights/best.pt")

results = model.predict(
    source="/content/phone_sticker_detection-1/test/images",
    save=True,
    conf=0.05
)
# Out:
# image 1/20 /content/phone_sticker_detection-1/test/images/087_JPG_JPG.rf.e234ed1fb9e0adc6f60dd6e6c3e9c6a9.jpg: 640x640 6 lenss, 1 phone, 4 stickers, 21.3ms
# image 2/20 /content/phone_sticker_detection-1/test/images/102_JPG_JPG.rf.6300a182ffc98f59c0541b217d57561b.jpg: 640x640 1 lens, 1 phone, 2 stickers, 20.9ms
# image 3/20 /content/phone_sticker_detection-1/test/images/111_JPG_JPG.rf.206450f04afbfdd1a3eaa0992d12be73.jpg: 640x640 1 phone, 1 sticker, 20.8ms
# image 4/20 /content/phone_sticker_detection-1/test/images/117_JPG_JPG.rf.4031b76757e28b6262a729814c4ac1ba.jpg: 640x640 1 phone, 1 sticker, 20.8ms
# image 5/20 /content/phone_sticker_detection-1/test/images/127_JPG_JPG.rf.e0f4f4d2da497763849f5627e3eabbc0.jpg: 640x640 1 lens, 1 phone, 1 sticker, 20.9ms
# image 6/20 /content/phone_sticker_detection-1/test/images/227_JPG_JPG.rf.fcb7e3e927fa13e4f2faa5f03d95ed7f.jpg: 640x640 3 lenss, 1 phone, 1 sticker, 22.8ms
# ...
